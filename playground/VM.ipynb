# %%
class VM:
    def __init__(self):
        self._registers = { 'i':0, 's':-1 }
        self._stack = []
        self._prog = []
        self._state = False
        self.__exec = {
            'LDC': self._LDC,
            'LDV': self._LDV,
            'ADD': self._ADD,
            'SUB': self._SUB,
            'MULT': self._MULT,
            'DIVI': self._DIVI,
            'INV': self._INV,
            'AND': self._AND,
            'OR': self._OR,
            'NEG': self._NEG,
            'CME': self._CME,
            'CMA': self._CMA,
            'CEQ': self._CEQ,
            'CDIF': self._CDIF,
            'CMEQ': self._CMEQ,
            'CMAQ': self._CMAQ,
            'START': self._START,
            'HLT': self._HLT,
            'STR': self._STR,
            'JMP': self._JMP,
            'JMPF': self._JMPF,
            'NULL': self._NULL,
            'RD': self._RD,
            'PRN': self._PRN,
            'ALLOC': self._ALLOC,
            'DALLOC': self._DALLOC,
            'CALL': self._CALL,
            'RETURN': self._RETURN
        }
        self._implicitIncI = True
        self._debugMode = False
        
    def _incI(self):
        self._registers['i'] += 1
        
    def _decI(self):
        self._registers['i'] -= 1
        
    def _incS(self):
        self._registers['s'] += 1
        
    def _decS(self):
        self._registers['s'] -= 1
        
    def _getI(self):
        return self._registers['i']
        
    def _getS(self):
        return self._registers['s']
    
    def _parseInt(self, x):
        return int(x)
    
    def _parseTuple(self, x, d=0):
        a, b = x.split(',')
        return int(a), int(b)
    
    def _parseLabel(self, x): # TODO implement this mess
        for idx, line in enumerate(self._prog):
            if x == line[0]:
                return idx
        return 0
    
    def _push(self, x, d=0):
        try:
            self._stack[self._getS()+d] = x
        except IndexError:
            self._stack.append(x)
    
    def _pushAt(self, x, p):
        self._stack[p] = x
        
    def _fetch(self, x):
        try:
            return self._stack[x]
        except IndexError:
            return 0
    
    def _pop(self, d=0):
        return self._stack[self._getS()+d]
    
    def _true(self, d=0):
        return self._pop(d=d) == 1
    
    def _false(self, d=0):
        return self._pop(d=d) == 0
    
    def _dbg(self, txt):
        if self._debugMode:
            print(txt)
        
    def _LDC(self, x):
        self._incS()
        self._push(self._parseInt(x))
        
    def _LDV(self, x):
        self._incS()
        self._push(self._fetch(self._parseInt(x)))
        
    def _ADD(self, x):
        self._push(self._pop(d=-1) + self._pop(), d=-1)
        self._decS()
        
    def _SUB(self, x):
        self._push(self._pop(d=-1) - self._pop(), d=-1)
        self._decS()
        
    def _MULT(self, x):
        self._push(self._pop(d=-1) * self._pop(), d=-1)
        self._decS()
        
    def _DIVI(self, x):
        self._push(self._pop(d=-1) // self._pop(), d=-1)
        self._decS()
        
    def _INV(self, x):
        self._push(-1 * self._pop())
        
    def _AND(self, x):
        self._push(1 if self._true() and self._true(d=-1) else 0, d=-1)
        self._decS()
        
    def _OR(self, x):
        self._push(1 if self._true() or self._true(d=-1) else 0, d=-1)
        self._decS()
        
    def _NEG(self, x):
        self._push(1 - self._pop())
        
    def _CME(self, x):
        self._push(1 if self._pop(d=-1) < self._pop() else 0, d=-1)
        self._decS()
        
    def _CMA(self, x):
        self._push(1 if self._pop(d=-1) > self._pop() else 0, d=-1)
        self._decS()
        
    def _CEQ(self, x):
        self._push(1 if self._pop(d=-1) == self._pop() else 0, d=-1)
        self._decS()
        
    def _CDIF(self, x):
        self._push(1 if self._pop(d=-1) != self._pop() else 0, d=-1)
        self._decS()
        
    def _CMEQ(self, x):
        self._push(1 if self._pop(d=-1) <= self._pop() else 0, d=-1)
        self._decS()
        
    def _CMAQ(self, x):
        self._push(1 if self._pop(d=-1) >= self._pop() else 0, d=-1)
        self._decS()
        
    def _START(self, x):
        self._registers['s'] = -1
        
    def _HLT(self, x):
        self._state = False
        
    def _STR(self, x):
        self._stack[self._parseInt(x)] = self._pop()
        self._decS()
        
    def _JMP(self, x):
        self._registers['i'] = self._parseLabel(x)
        self._implicitIncI = False
        
    def _JMPF(self, x):
        self._registers['i'] = self._parseLabel(x) if self._false() else self._registers['i'] + 1
        self._decS()
        self._implicitIncI = False
        
    def _NULL(self, x):
        pass
    
    def _RD(self, x):
        self._incS()
        self._push(int(input(">"))) #TODO add input logic
        
    def _PRN(self, x):
        print(self._pop()) #TODO add output logic
        self._decS()
        
    def _ALLOC(self, x):
        m, n = self._parseTuple(x)
        for k in range(n):
            self._incS()
            self._push(self._fetch(m + k))
        
    def _DALLOC(self, x):
        m, n = self._parseTuple(x)
        for k in range(n-1, -1, -1):
            self._dbg("Dealoccing {} ({})".format(self._pop(), k))
            self._pushAt(self._pop(), m + k)
            self._decS()
            
    def _CALL(self, x):
        self._incS()
        self._push(self._getI() + 1)
        self._registers['i'] = self._parseLabel(x)
        self._implicitIncI = False
        
    def _RETURN(self, x):
        self._registers['i'] = self._pop()
        self._decS()
        self._implicitIncI = False
        
    def toStackString(self):
        return "["+",".join([str(item) for item in self._stack[:self._registers['s']+1]])+"]"
        
    def toString(self):
        return "VM [i={}, s={}]".format(self._registers['i'], self._registers['s']) + self.toStackString()
        
    def loadProgram(self, program):
        self._prog = program
        
    def execute(self):
        self._state = True
        while self._state:
            self.step()
            
    def step(self):
        if not self._state:
            return 0
        cmd = self._prog[self._getI()]
        aux = cmd[2] if len(cmd) > 2 else None
        args = cmd[1] if len(cmd) > 1 else None
        cmd = cmd[0]
        self._dbg("CMD={}, ARGS={}, AUX={}".format(cmd, args, aux))
        if cmd in self.__exec:
            self.__exec[cmd](args)
        else:
            self._dbg("CMD {} not found in list".format(cmd))
            self.__exec[args](aux)
        if self._implicitIncI:
            self._incI()
        self._implicitIncI = True

# %%
code = """START
ALLOC 0,2
JMP L1
L2 NULL
ALLOC 2,1
LDV 0
STR 2
LDV 0
LDC 1
SUB
STR 0
LDV 2
LDC 1
CMA
JMPF L3
CALL L2
JMP L4
L3 NULL
LDC 1
STR 1
L4 NULL
LDV 1
LDV 2
MULT
STR 1
DALLOC 2,1
RETURN
L1 NULL
RD
STR 0
CALL L2
LDV 0
PRN
LDV 1
PRN
DALLOC 0,2
HLT
"""

# %%
prog = [line.split() for line in code.split('\n')]

# %%
vm = VM()

vm.loadProgram(prog)
vm._state = True
vm._debugMode = True

step = 0

while vm._state:
    print(vm.toString())
    print("{}->".format(step), end="")
    vm.step()
    step += 1
    print("")
# Out:
# VM [i=0, s=-1][]
# 0->CMD=START, ARGS=None, AUX=None
#
# VM [i=1, s=-1][]
# 1->CMD=ALLOC, ARGS=0,2, AUX=None
#
# VM [i=2, s=1][0,0]
# 2->CMD=JMP, ARGS=L1, AUX=None
#
# VM [i=27, s=1][0,0]
# 3->CMD=L1, ARGS=NULL, AUX=None
# CMD L1 not found in list
#
# VM [i=28, s=1][0,0]
# 4->CMD=RD, ARGS=None, AUX=None
# >6
#
# VM [i=29, s=2][0,0,6]
# 5->CMD=STR, ARGS=0, AUX=None
#
# VM [i=30, s=1][6,0]
# 6->CMD=CALL, ARGS=L2, AUX=None
#
# VM [i=3, s=2][6,0,31]
# 7->CMD=L2, ARGS=NULL, AUX=None
# CMD L2 not found in list
#
# VM [i=4, s=2][6,0,31]
# 8->CMD=ALLOC, ARGS=2,1, AUX=None
#
# VM [i=5, s=3][6,0,31,31]
# 9->CMD=LDV, ARGS=0, AUX=None
#
# VM [i=6, s=4][6,0,31,31,6]
# 10->CMD=STR, ARGS=2, AUX=None
#
# VM [i=7, s=3][6,0,6,31]
# 11->CMD=LDV, ARGS=0, AUX=None
#
# VM [i=8, s=4][6,0,6,31,6]
# 12->CMD=LDC, ARGS=1, AUX=None
#
# VM [i=9, s=5][6,0,6,31,6,1]
# 13->CMD=SUB, ARGS=None, AUX=None
#
# VM [i=10, s=4][6,0,6,31,5]
# 14->CMD=STR, ARGS=0, AUX=None
#
# VM [i=11, s=3][5,0,6,31]
# 15->CMD=LDV, ARGS=2, AUX=None
#
# VM [i=12, s=4][5,0,6,31,6]
# 16->CMD=LDC, ARGS=1, AUX=None
#
# VM [i=13, s=5][5,0,6,31,6,1]
# 17->CMD=CMA, ARGS=None, AUX=None
#
# VM [i=14, s=4][5,0,6,31,1]
# 18->CMD=JMPF, ARGS=L3, AUX=None
#
# VM [i=15, s=3][5,0,6,31]
# 19->CMD=CALL, ARGS=L2, AUX=None
#
# VM [i=3, s=4][5,0,6,31,16]
# 20->CMD=L2, ARGS=NULL, AUX=None
# CMD L2 not found in list
#
# VM [i=4, s=4][5,0,6,31,16]
# 21->CMD=ALLOC, ARGS=2,1, AUX=None
#
# VM [i=5, s=5][5,0,6,31,16,6]
# 22->CMD=LDV, ARGS=0, AUX=None
#
# VM [i=6, s=6][5,0,6,31,16,6,5]
# 23->CMD=STR, ARGS=2, AUX=None
#
# VM [i=7, s=5][5,0,5,31,16,6]
# 24->CMD=LDV, ARGS=0, AUX=None
#
# VM [i=8, s=6][5,0,5,31,16,6,5]
# 25->CMD=LDC, ARGS=1, AUX=None
#
# VM [i=9, s=7][5,0,5,31,16,6,5,1]
# 26->CMD=SUB, ARGS=None, AUX=None
#
# VM [i=10, s=6][5,0,5,31,16,6,4]
# 27->CMD=STR, ARGS=0, AUX=None
#
# VM [i=11, s=5][4,0,5,31,16,6]
# 28->CMD=LDV, ARGS=2, AUX=None
#
# VM [i=12, s=6][4,0,5,31,16,6,5]
# 29->CMD=LDC, ARGS=1, AUX=None
#
# VM [i=13, s=7][4,0,5,31,16,6,5,1]
# 30->CMD=CMA, ARGS=None, AUX=None
#
# VM [i=14, s=6][4,0,5,31,16,6,1]
# 31->CMD=JMPF, ARGS=L3, AUX=None
#
# VM [i=15, s=5][4,0,5,31,16,6]
# 32->CMD=CALL, ARGS=L2, AUX=None
#
# VM [i=3, s=6][4,0,5,31,16,6,16]
# 33->CMD=L2, ARGS=NULL, AUX=None
# CMD L2 not found in list
#
# VM [i=4, s=6][4,0,5,31,16,6,16]
# 34->CMD=ALLOC, ARGS=2,1, AUX=None
#
# VM [i=5, s=7][4,0,5,31,16,6,16,5]
# 35->CMD=LDV, ARGS=0, AUX=None
#
# VM [i=6, s=8][4,0,5,31,16,6,16,5,4]
# 36->CMD=STR, ARGS=2, AUX=None
#
# VM [i=7, s=7][4,0,4,31,16,6,16,5]
# 37->CMD=LDV, ARGS=0, AUX=None
#
# VM [i=8, s=8][4,0,4,31,16,6,16,5,4]
# 38->CMD=LDC, ARGS=1, AUX=None
#
# VM [i=9, s=9][4,0,4,31,16,6,16,5,4,1]
# 39->CMD=SUB, ARGS=None, AUX=None
#
# VM [i=10, s=8][4,0,4,31,16,6,16,5,3]
# 40->CMD=STR, ARGS=0, AUX=None
#
# VM [i=11, s=7][3,0,4,31,16,6,16,5]
# 41->CMD=LDV, ARGS=2, AUX=None
#
# VM [i=12, s=8][3,0,4,31,16,6,16,5,4]
# 42->CMD=LDC, ARGS=1, AUX=None
#
# VM [i=13, s=9][3,0,4,31,16,6,16,5,4,1]
# 43->CMD=CMA, ARGS=None, AUX=None
#
# VM [i=14, s=8][3,0,4,31,16,6,16,5,1]
# 44->CMD=JMPF, ARGS=L3, AUX=None
#
# VM [i=15, s=7][3,0,4,31,16,6,16,5]
# 45->CMD=CALL, ARGS=L2, AUX=None
#
# VM [i=3, s=8][3,0,4,31,16,6,16,5,16]
# 46->CMD=L2, ARGS=NULL, AUX=None
# CMD L2 not found in list
#
# VM [i=4, s=8][3,0,4,31,16,6,16,5,16]
# 47->CMD=ALLOC, ARGS=2,1, AUX=None
#
# VM [i=5, s=9][3,0,4,31,16,6,16,5,16,4]
# 48->CMD=LDV, ARGS=0, AUX=None
#
# VM [i=6, s=10][3,0,4,31,16,6,16,5,16,4,3]
# 49->CMD=STR, ARGS=2, AUX=None
#
# VM [i=7, s=9][3,0,3,31,16,6,16,5,16,4]
# 50->CMD=LDV, ARGS=0, AUX=None
#
# VM [i=8, s=10][3,0,3,31,16,6,16,5,16,4,3]
# 51->CMD=LDC, ARGS=1, AUX=None
#
# VM [i=9, s=11][3,0,3,31,16,6,16,5,16,4,3,1]
# 52->CMD=SUB, ARGS=None, AUX=None
#
# VM [i=10, s=10][3,0,3,31,16,6,16,5,16,4,2]
# 53->CMD=STR, ARGS=0, AUX=None
#
# VM [i=11, s=9][2,0,3,31,16,6,16,5,16,4]
# 54->CMD=LDV, ARGS=2, AUX=None
#
# VM [i=12, s=10][2,0,3,31,16,6,16,5,16,4,3]
# 55->CMD=LDC, ARGS=1, AUX=None
#
# VM [i=13, s=11][2,0,3,31,16,6,16,5,16,4,3,1]
# 56->CMD=CMA, ARGS=None, AUX=None
#
# VM [i=14, s=10][2,0,3,31,16,6,16,5,16,4,1]
# 57->CMD=JMPF, ARGS=L3, AUX=None
#
# VM [i=15, s=9][2,0,3,31,16,6,16,5,16,4]
# 58->CMD=CALL, ARGS=L2, AUX=None
#
# VM [i=3, s=10][2,0,3,31,16,6,16,5,16,4,16]
# 59->CMD=L2, ARGS=NULL, AUX=None
# CMD L2 not found in list
#
# VM [i=4, s=10][2,0,3,31,16,6,16,5,16,4,16]
# 60->CMD=ALLOC, ARGS=2,1, AUX=None
#
# VM [i=5, s=11][2,0,3,31,16,6,16,5,16,4,16,3]
# 61->CMD=LDV, ARGS=0, AUX=None
#
# VM [i=6, s=12][2,0,3,31,16,6,16,5,16,4,16,3,2]
# 62->CMD=STR, ARGS=2, AUX=None
#
# VM [i=7, s=11][2,0,2,31,16,6,16,5,16,4,16,3]
# 63->CMD=LDV, ARGS=0, AUX=None
#
# VM [i=8, s=12][2,0,2,31,16,6,16,5,16,4,16,3,2]
# 64->CMD=LDC, ARGS=1, AUX=None
#
# VM [i=9, s=13][2,0,2,31,16,6,16,5,16,4,16,3,2,1]
# 65->CMD=SUB, ARGS=None, AUX=None
#
# VM [i=10, s=12][2,0,2,31,16,6,16,5,16,4,16,3,1]
# 66->CMD=STR, ARGS=0, AUX=None
#
# VM [i=11, s=11][1,0,2,31,16,6,16,5,16,4,16,3]
# 67->CMD=LDV, ARGS=2, AUX=None
#
# VM [i=12, s=12][1,0,2,31,16,6,16,5,16,4,16,3,2]
# 68->CMD=LDC, ARGS=1, AUX=None
#
# VM [i=13, s=13][1,0,2,31,16,6,16,5,16,4,16,3,2,1]
# 69->CMD=CMA, ARGS=None, AUX=None
#
# VM [i=14, s=12][1,0,2,31,16,6,16,5,16,4,16,3,1]
# 70->CMD=JMPF, ARGS=L3, AUX=None
#
# VM [i=15, s=11][1,0,2,31,16,6,16,5,16,4,16,3]
# 71->CMD=CALL, ARGS=L2, AUX=None
#
# VM [i=3, s=12][1,0,2,31,16,6,16,5,16,4,16,3,16]
# 72->CMD=L2, ARGS=NULL, AUX=None
# CMD L2 not found in list
#
# VM [i=4, s=12][1,0,2,31,16,6,16,5,16,4,16,3,16]
# 73->CMD=ALLOC, ARGS=2,1, AUX=None
#
# VM [i=5, s=13][1,0,2,31,16,6,16,5,16,4,16,3,16,2]
# 74->CMD=LDV, ARGS=0, AUX=None
#
# VM [i=6, s=14][1,0,2,31,16,6,16,5,16,4,16,3,16,2,1]
# 75->CMD=STR, ARGS=2, AUX=None
#
# VM [i=7, s=13][1,0,1,31,16,6,16,5,16,4,16,3,16,2]
# 76->CMD=LDV, ARGS=0, AUX=None
#
# VM [i=8, s=14][1,0,1,31,16,6,16,5,16,4,16,3,16,2,1]
# 77->CMD=LDC, ARGS=1, AUX=None
#
# VM [i=9, s=15][1,0,1,31,16,6,16,5,16,4,16,3,16,2,1,1]
# 78->CMD=SUB, ARGS=None, AUX=None
#
# VM [i=10, s=14][1,0,1,31,16,6,16,5,16,4,16,3,16,2,0]
# 79->CMD=STR, ARGS=0, AUX=None
#
# VM [i=11, s=13][0,0,1,31,16,6,16,5,16,4,16,3,16,2]
# 80->CMD=LDV, ARGS=2, AUX=None
#
# VM [i=12, s=14][0,0,1,31,16,6,16,5,16,4,16,3,16,2,1]
# 81->CMD=LDC, ARGS=1, AUX=None
#
# VM [i=13, s=15][0,0,1,31,16,6,16,5,16,4,16,3,16,2,1,1]
# 82->CMD=CMA, ARGS=None, AUX=None
#
# VM [i=14, s=14][0,0,1,31,16,6,16,5,16,4,16,3,16,2,0]
# 83->CMD=JMPF, ARGS=L3, AUX=None
#
# VM [i=17, s=13][0,0,1,31,16,6,16,5,16,4,16,3,16,2]
# 84->CMD=L3, ARGS=NULL, AUX=None
# CMD L3 not found in list
#
# VM [i=18, s=13][0,0,1,31,16,6,16,5,16,4,16,3,16,2]
# 85->CMD=LDC, ARGS=1, AUX=None
#
# VM [i=19, s=14][0,0,1,31,16,6,16,5,16,4,16,3,16,2,1]
# 86->CMD=STR, ARGS=1, AUX=None
#
# VM [i=20, s=13][0,1,1,31,16,6,16,5,16,4,16,3,16,2]
# 87->CMD=L4, ARGS=NULL, AUX=None
# CMD L4 not found in list
#
# VM [i=21, s=13][0,1,1,31,16,6,16,5,16,4,16,3,16,2]
# 88->CMD=LDV, ARGS=1, AUX=None
#
# VM [i=22, s=14][0,1,1,31,16,6,16,5,16,4,16,3,16,2,1]
# 89->CMD=LDV, ARGS=2, AUX=None
#
# VM [i=23, s=15][0,1,1,31,16,6,16,5,16,4,16,3,16,2,1,1]
# 90->CMD=MULT, ARGS=None, AUX=None
#
# VM [i=24, s=14][0,1,1,31,16,6,16,5,16,4,16,3,16,2,1]
# 91->CMD=STR, ARGS=1, AUX=None
#
# VM [i=25, s=13][0,1,1,31,16,6,16,5,16,4,16,3,16,2]
# 92->CMD=DALLOC, ARGS=2,1, AUX=None
# Dealoccing 2 (0)
#
# VM [i=26, s=12][0,1,2,31,16,6,16,5,16,4,16,3,16]
# 93->CMD=RETURN, ARGS=None, AUX=None
#
# VM [i=16, s=11][0,1,2,31,16,6,16,5,16,4,16,3]
# 94->CMD=JMP, ARGS=L4, AUX=None
#
# VM [i=20, s=11][0,1,2,31,16,6,16,5,16,4,16,3]
# 95->CMD=L4, ARGS=NULL, AUX=None
# CMD L4 not found in list
#
# VM [i=21, s=11][0,1,2,31,16,6,16,5,16,4,16,3]
# 96->CMD=LDV, ARGS=1, AUX=None
#
# VM [i=22, s=12][0,1,2,31,16,6,16,5,16,4,16,3,1]
# 97->CMD=LDV, ARGS=2, AUX=None
#
# VM [i=23, s=13][0,1,2,31,16,6,16,5,16,4,16,3,1,2]
# 98->CMD=MULT, ARGS=None, AUX=None
#
# VM [i=24, s=12][0,1,2,31,16,6,16,5,16,4,16,3,2]
# 99->CMD=STR, ARGS=1, AUX=None
#
# VM [i=25, s=11][0,2,2,31,16,6,16,5,16,4,16,3]
# 100->CMD=DALLOC, ARGS=2,1, AUX=None
# Dealoccing 3 (0)
#
# VM [i=26, s=10][0,2,3,31,16,6,16,5,16,4,16]
# 101->CMD=RETURN, ARGS=None, AUX=None
#
# VM [i=16, s=9][0,2,3,31,16,6,16,5,16,4]
# 102->CMD=JMP, ARGS=L4, AUX=None
#
# VM [i=20, s=9][0,2,3,31,16,6,16,5,16,4]
# 103->CMD=L4, ARGS=NULL, AUX=None
# CMD L4 not found in list
#
# VM [i=21, s=9][0,2,3,31,16,6,16,5,16,4]
# 104->CMD=LDV, ARGS=1, AUX=None
#
# VM [i=22, s=10][0,2,3,31,16,6,16,5,16,4,2]
# 105->CMD=LDV, ARGS=2, AUX=None
#
# VM [i=23, s=11][0,2,3,31,16,6,16,5,16,4,2,3]
# 106->CMD=MULT, ARGS=None, AUX=None
#
# VM [i=24, s=10][0,2,3,31,16,6,16,5,16,4,6]
# 107->CMD=STR, ARGS=1, AUX=None
#
# VM [i=25, s=9][0,6,3,31,16,6,16,5,16,4]
# 108->CMD=DALLOC, ARGS=2,1, AUX=None
# Dealoccing 4 (0)
#
# VM [i=26, s=8][0,6,4,31,16,6,16,5,16]
# 109->CMD=RETURN, ARGS=None, AUX=None
#
# VM [i=16, s=7][0,6,4,31,16,6,16,5]
# 110->CMD=JMP, ARGS=L4, AUX=None
#
# VM [i=20, s=7][0,6,4,31,16,6,16,5]
# 111->CMD=L4, ARGS=NULL, AUX=None
# CMD L4 not found in list
#
# VM [i=21, s=7][0,6,4,31,16,6,16,5]
# 112->CMD=LDV, ARGS=1, AUX=None
#
# VM [i=22, s=8][0,6,4,31,16,6,16,5,6]
# 113->CMD=LDV, ARGS=2, AUX=None
#
# VM [i=23, s=9][0,6,4,31,16,6,16,5,6,4]
# 114->CMD=MULT, ARGS=None, AUX=None
#
# VM [i=24, s=8][0,6,4,31,16,6,16,5,24]
# 115->CMD=STR, ARGS=1, AUX=None
#
# VM [i=25, s=7][0,24,4,31,16,6,16,5]
# 116->CMD=DALLOC, ARGS=2,1, AUX=None
# Dealoccing 5 (0)
#
# VM [i=26, s=6][0,24,5,31,16,6,16]
# 117->CMD=RETURN, ARGS=None, AUX=None
#
# VM [i=16, s=5][0,24,5,31,16,6]
# 118->CMD=JMP, ARGS=L4, AUX=None
#
# VM [i=20, s=5][0,24,5,31,16,6]
# 119->CMD=L4, ARGS=NULL, AUX=None
# CMD L4 not found in list
#
# VM [i=21, s=5][0,24,5,31,16,6]
# 120->CMD=LDV, ARGS=1, AUX=None
#
# VM [i=22, s=6][0,24,5,31,16,6,24]
# 121->CMD=LDV, ARGS=2, AUX=None
#
# VM [i=23, s=7][0,24,5,31,16,6,24,5]
# 122->CMD=MULT, ARGS=None, AUX=None
#
# VM [i=24, s=6][0,24,5,31,16,6,120]
# 123->CMD=STR, ARGS=1, AUX=None
#
# VM [i=25, s=5][0,120,5,31,16,6]
# 124->CMD=DALLOC, ARGS=2,1, AUX=None
# Dealoccing 6 (0)
#
# VM [i=26, s=4][0,120,6,31,16]
# 125->CMD=RETURN, ARGS=None, AUX=None
#
# VM [i=16, s=3][0,120,6,31]
# 126->CMD=JMP, ARGS=L4, AUX=None
#
# VM [i=20, s=3][0,120,6,31]
# 127->CMD=L4, ARGS=NULL, AUX=None
# CMD L4 not found in list
#
# VM [i=21, s=3][0,120,6,31]
# 128->CMD=LDV, ARGS=1, AUX=None
#
# VM [i=22, s=4][0,120,6,31,120]
# 129->CMD=LDV, ARGS=2, AUX=None
#
# VM [i=23, s=5][0,120,6,31,120,6]
# 130->CMD=MULT, ARGS=None, AUX=None
#
# VM [i=24, s=4][0,120,6,31,720]
# 131->CMD=STR, ARGS=1, AUX=None
#
# VM [i=25, s=3][0,720,6,31]
# 132->CMD=DALLOC, ARGS=2,1, AUX=None
# Dealoccing 31 (0)
#
# VM [i=26, s=2][0,720,31]
# 133->CMD=RETURN, ARGS=None, AUX=None
#
# VM [i=31, s=1][0,720]
# 134->CMD=LDV, ARGS=0, AUX=None
#
# VM [i=32, s=2][0,720,0]
# 135->CMD=PRN, ARGS=None, AUX=None
# 0
#
# VM [i=33, s=1][0,720]
# 136->CMD=LDV, ARGS=1, AUX=None
#
# VM [i=34, s=2][0,720,720]
# 137->CMD=PRN, ARGS=None, AUX=None
# 720
#
# VM [i=35, s=1][0,720]
# 138->CMD=DALLOC, ARGS=0,2, AUX=None
# Dealoccing 720 (1)
# Dealoccing 0 (0)
#
# VM [i=36, s=-1][]
# 139->CMD=HLT, ARGS=None, AUX=None

# %%
vm = VM()

vm.loadProgram(prog)
vm._state = True

vm.execute()
# Out:
# >6
# 0
# 720
